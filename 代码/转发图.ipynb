# %%
import csv
with open('MpioCAcEi.csv', 'r') as read_obj:
        csv_reader = csv.reader(read_obj)
        list_of_csv = list(csv_reader)

# %%
from pyecharts import options as opts
from pyecharts.charts import Sankey, Timeline
from pyecharts.faker import Faker

# %%
import json
from pyecharts import options as opts
from pyecharts.charts import Sankey

with open(title+'.json', "r", encoding="utf-8") as f:
    j = json.load(f)
c = (
    Sankey(
        init_opts=opts.InitOpts(width="1600px", height="800px")
        
    )
    .add(
        "sankey",
        nodes=j["nodes"],
        links=j["links"],
        pos_top="10%",
     
        levels=[
            opts.SankeyLevelsOpts(
                depth=0,
                itemstyle_opts=opts.ItemStyleOpts(color="#fbb4ae"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=1,
                itemstyle_opts=opts.ItemStyleOpts(color="#b3cde3"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=2,
                itemstyle_opts=opts.ItemStyleOpts(color="#ccebc5"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=3,
                itemstyle_opts=opts.ItemStyleOpts(color="#decbe4"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
        ],
        
        linestyle_opt=opts.LineStyleOpts(curve=0.5),
        label_opts=opts.LabelOpts(position="right"),
        focus_node_mode="adjacency",
        
        
    )
    .set_global_opts(
        
        title_opts=opts.TitleOpts(title="Sankey-Level Settings"),
        tooltip_opts=opts.TooltipOpts(trigger="item", trigger_on="mousemove"),
        
    )
    .render("sankey_with_level_setting111.html")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from pyecharts import options as opts
#       3 from pyecharts.charts import Sankey
# ----> 5 with open(title+'.json', "r", encoding="utf-8") as f:
#       6     j = json.load(f)
#       7 c = (
#       8     Sankey(
#       9         init_opts=opts.InitOpts(width="1600px", height="800px")
#    (...)
#      53     .render("sankey_with_level_setting111.html")
#      54 )
#
# NameError: name 'title' is not defined

# %%
import asyncio


import pyecharts.options as opts
from pyecharts.charts import Sankey

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://echarts.apache.org/examples/editor.html?c=sankey-energy

目前无法实现的功能:

1、label 和图的层次有点问题
"""


async def get_json_data(url: str) -> dict:
    async with ClientSession(connector=TCPConnector(ssl=False)) as session:
        async with session.get(url=url) as response:
            return await response.json()


# 获取官方的数据
with open("filename.json", "r", encoding="utf-8") as f:
    data  = json.load(f)

(
    Sankey()
    .add(
        series_name="",
        nodes=data["nodes"],
        links=data["links"],
        itemstyle_opts=opts.ItemStyleOpts(border_width=1, border_color="#aaa"),
        linestyle_opt=opts.LineStyleOpts(color="source", curve=0.5, opacity=0.5),
        tooltip_opts=opts.TooltipOpts(trigger_on="mousemove"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Sankey Diagram"))
    .render("sankey_diagram.html")
)
# Out:
# '/Users/weizhihao/Documents/GitHub/biye_weibo/代码/sankey_diagram.html'

# %%
kk=[]




for i in range(len(list_of_csv)-1):
    i=i+1
    kk.append(list_of_csv[i][1])
    kk.append(list_of_csv[i][2])


kk = list(set(kk))

# %%
len(kk)
# Out:
# 113

# %%
dict={"nodes":list1,"links":list2}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dict={"nodes":list1,"links":list2}
#
# NameError: name 'list1' is not defined

# %%
jsontext = {"nodes":[],"links":[]}
for row in kk:
    jsontext["nodes"].append({"name":row})
for row in list_of_csv: 
    
    jsontext["links"].append({"source":row[1],"target":row[2],"value":row[3]})

# %%
jsontext=json.dumps(jsontext)

# %%
file = open('filename.json', 'w')

file.write(jsontext)

file.close()

# %%
type(jsontext)
# Out:
# str

# %%
jsontext
# Out:
# '{"nodes": [{"name": "\\u8096\\u6218\\u5f71\\u97f3\\u4f1a\\u5b98\\u5fae"}, {"name": "\\u8096\\u6218\\u5de5\\u4f5c\\u5ba4"}, {"name": "\\u767d\\u9c7cyuzq2009"}, {"name": "\\u63d0\\u62c9\\u7c73\\u82cf\\u914d\\u5267\\u4e36"}, {"name": "\\u8096\\u62181005\\u53f7\\u5b89\\u5229\\u7b52"}, {"name": "lily99996666"}, {"name": "\\u88ab\\u9524\\u6b7b\\u5728\\u5751\\u5e95"}, {"name": "\\u548c\\u7f8e\\u65f6\\u5149"}, {"name": "\\u5c1a\\u597d\\u7684\\u9752\\u6625xz"}, {"name": "\\u9752\\u9752\\u7684\\u9edb\\u8272"}, {"name": "\\u5b89\\u9713789"}, {"name": "\\u968f\\u98ce\\u98de\\u626cxyw"}, {"name": "\\u65ad\\u820d\\u79bb\\u81ea\\u96be\\u5fd8"}, {"name": "\\u534a\\u5206\\u6d45\\u590f_"}, {"name": "\\u60ca\\u4e16\\u516c\\u5b50"}, {"name": "\\u6e05\\u98ce\\u552f\\u6218\\u800c\\u6765"}, {"name": "\\u6211\\u662f\\u5c0f\\u8017\\u554a"}, {"name": "\\u751c\\u6a59\\u5c0f\\u5a1c"}, {"name": "\\u4f0a\\u4eba\\u67ad\\u8d5e"}, {"name": "\\u6d45\\u590f\\u9633\\u5149ai"}, {"name": "\\u79e6\\u65f6\\u660e\\u6708qinsmoon"}, {"name": "\\u6211\\u5fc3\\u6211\\u4e3bCAO"}, {"name": "\\u60f9\\u6211\\u8001\\u516c\\u4f60\\u5c31\\u6b7b\\u5b9a\\u4e86"}, {"name": "\\u4e3d\\u8389\\u65af_\\u65fa"}, {"name": "\\u9752\\u827283443"}, {"name": "\\u68a6\\u66e6\\u8c46\\u8c46"}, {"name": "\\u845b\\u845b\\u5f00\\u5fc3"}, {"name": "\\u626f\\u626f\\u5c31\\u662f\\u6211"}, {"name": "\\u5b89\\u5a1c\\u6218\\u6218\\u7684\\u5c0f\\u98de\\u4fa0"}, {"name": "\\u51cc\\u67ab\\u9759\\u5fc32020"}, {"name": "\\u5fae\\u96e8\\u6fdb\\u6fdb"}, {"name": "\\u591c\\u672a\\u592eyez"}, {"name": "\\u8424\\u8424\\u706b\\u4e4b\\u68ee\\u6797"}, {"name": "\\u8096\\u6218\\u7f51\\u5ba3\\u5b98\\u5fae"}, {"name": "\\u6a59\\u82b1\\u5154\\u5b50sean"}, {"name": "\\u7231\\u5154\\u8054\\u76df\\u4e00\\u53f7\\u536b"}, {"name": "\\u58a8\\u67d3\\u66e61005"}, {"name": "\\u7ec8\\u751f\\u7231\\u5154\\u4eba\\u58eb"}, {"name": "\\u8096\\u67d3\\u67d3\\u7684\\u5c0f\\u5154\\u7259"}, {"name": "\\u8fd9\\u6837\\u76f8\\u7231U"}, {"name": "\\u51b0\\u7c89\\u51c9\\u867e\\u5c0f\\u706b\\u9505_"}, {"name": "MissLiu_1005"}, {"name": "\\u624b\\u6367\\u661f\\u5149\\u9001\\u4f60"}, {"name": "\\u53d6\\u4e2a\\u6635\\u79f0\\u603b\\u662f\\u4e0d\\u80fd\\u4f7f\\u7528"}, {"name": "Nana_1005"}, {"name": "xuhong202004"}, {"name": "\\u5154\\u6bdb\\u62a4\\u7406\\u624b\\u518c"}, {"name": "\\u8096\\u8096\\u96c5\\u6960"}, {"name": "\\u96ef\\u5b50007728"}, {"name": "jessie\\u97eb"}, {"name": "\\u597d\\u4eba\\u4e00\\u751f\\u5e73\\u5b89haoya"}, {"name": "\\u53d6\\u4e2a\\u540d\\u5b57\\u60f3\\u5230\\u534a\\u591c"}, {"name": "\\u5468\\u5468\\u6709\\u94b1daytoy"}, {"name": "\\u90a3\\u5e74\\u7684\\u51491221"}, {"name": "\\u6109\\u5feb\\u5730\\u547c\\u5438"}, {"name": "\\u66fc\\u4ec0\\u4e48\\u57fa\\u4ec0\\u4e48\\u5eb7\\u4ec0\\u4e48"}, {"name": "\\u4e3a\\u6218\\u800c\\u67651005_XZ"}, {"name": "\\u78ca\\u843d\\u7684\\u91ce\\u5fc3\\u5bb6865"}, {"name": "\\u871c\\u8c46\\u8c46\\u6c99"}, {"name": "lisa\\u7231\\u6843\\u6843"}, {"name": "Selamm\\u521d\\u5fc3"}, {"name": "\\u660e\\u6708\\u5728dyl"}, {"name": "\\u65e0\\u8bed\\u6d1b"}, {"name": "\\u80e1\\u841d\\u535c\\u4e0d\\u662f\\u841d\\u535czz"}, {"name": "\\u6708\\u513f\\u5f2f\\u8170123456"}, {"name": "\\u7a97\\u5916\\u68a7\\u6850\\u53d1\\u65b0\\u82bd"}, {"name": "\\u730b\\u730b\\u5927\\u961f\\u957f"}, {"name": "\\u5c0f\\u7ea2\\u82b1\\u7684\\u5e78\\u798f\\u751f\\u6d3b"}, {"name": "\\u5446\\u6843\\u71da"}, {"name": "\\u51ac\\u81f3\\u83ab\\u79bb1005"}, {"name": "\\u8096\\u5c0f\\u8d5e\\u7684\\u575a\\u679c"}, {"name": "ChoiMacchiato"}, {"name": "\\u51cc\\u67ab\\u9759\\u5fc3_d"}, {"name": "\\u840c\\u4e5d\\u6708\\u771f\\u53ef\\u7231"}, {"name": "\\u59ca\\u59b9\\u62a5"}, {"name": "\\u4f60\\u522b\\u8bf4\\u68a6\\u60f3\\u9065\\u4e0d\\u53ef\\u53ca"}, {"name": "\\u53ef\\u82e6\\u53ef\\u4e50\\u768477"}, {"name": "\\u98de\\u7fbd\\u91cd\\u5343"}, {"name": "\\u76db\\u9633\\u662f\\u6211\\u7684\\u5c0f\\u54e5\\u54e5"}, {"name": "\\u674e\\u7f8e\\u7f8e\\u8bf6"}, {"name": "\\u949f\\u7075\\u6bd3\\u79c0\\u5730\\u4e0b\\u5ba4"}, {"name": "\\u7ea2\\u ...

# %%
title="肖战工作室"
sql_3 = f'SELECT * FROM weiboforword where title="{title}"'
db = MysqlUtil()
count_number = db.fetchall(sql_3)
kk=[]
# 数据库方式
for row in count_number:
    print(row["source"])
    kk.append(row["source"])
    kk.append(row["target"])
kk = list(set(kk))
import json

# 数据库
jsontext = {"nodes":[],"links":[]}
for row in kk:
    jsontext["nodes"].append({"name":row})
for row in count_number: 
    jsontext["links"].append({"source":row["source"],"target":row["target"],"value":row["value"]})   
jsontext=json.dumps(jsontext)
file = open(title+'.json', 'w')
file.write(jsontext)
file.close()
# Out:
# 肖战影音会官微
# 1005号肥虾指南
# 肖战网宣官微
# 兔毛护理手册
# 1005号虾虾能量客栈
# 肖战1005号安利筒
# 惊世公子
# Nana_1005
# 呆桃燚
# 你别说梦想遥不可及
# 肖小赞的坚果
# 无语洛
# 惹我老公你就死定了
# 肖肖-静静
# wjq_1128
# 半糖甜岛
# 手捧星光送你
# ChoiMacchiato
# 沫沫ZC33
# 微雨濛濛
# 战兔仰慕者
# 爱兔联盟一号卫
# 猋猋大队长
# 浅夏阳光ai
# 勇敢的兔子v
# Nana_1005
# 一菜二白
# 肖肖-静静
# 磕颜日志
# 肖染染的小兔牙
# 提拉米苏配剧丶
# 萌九月真可爱
# 肖肖雅楠
# 战兔仰慕者
# 爱兔联盟一号卫
# 猋猋大队长
# 肖肖-静静
# 可苦可乐的77
# 李美美诶
# 肖染染的小兔牙
# 肖染染的小兔牙
# 可苦可乐的77
# 肖肖-静静
# 肖染染的小兔牙
# 小红花的幸福生活
# 战兔仰慕者
# 爱兔联盟一号卫
# 猋猋大队长
# 惊世公子
# Selamm初心
# lisa爱桃桃
# 肖染染的小兔牙
# 梦曦豆豆
# Selamm初心
# 肖肖-静静
# 断舍离自难忘
# 萤萤火之森林
# 时影见到的第一个女人
# 葛葛开心
# 蜜豆豆沙
# 丽莉斯_旺
# 随白桃心
# 凌枫静心_d
# 凌枫静心2020
# 白鱼yuzq2009
# 戛娃央宗
# 扯扯就是我
# MissLiu_1005
# 门门好成绩
# 重庆大辣椒123
# 暮春浅夏_
# 暮春浅夏_
# 暮春浅夏_
# 暮春浅夏_
# 纪红玥
# 暮春浅夏_
# 暮春浅夏_
# 终生爱兔人士
# 终生爱兔人士
# 战兔仰慕者
# 终生爱兔人士
# 战兔仰慕者
# 爱兔联盟一号卫
# 甜橙小娜
# 曼什么基什么康什么
# 钟灵毓秀地下室
# 盛阳是我的小哥哥
# 乌瑟尔小破孩
# CY酱的孤独狗5R
# 红玥ricky
# 橙花兔子sean
# 那年的光1221
# 安霓789
# 纪红玥
# 窗外梧桐发新芽
# 夜未央yez
# 这样相爱U
# 纪红玥
# 纪红玥
# 窗外梧桐发新芽
# 夜未央yez
# 这样相爱U
# 纪红玥
# 我心我主CAO
# 橙花兔子sean
# 窗外梧桐发新芽
# 橙花兔子sean
# 纪红玥
# 白茶柠檬兔
# 窗外梧桐发新芽
# 终生爱兔人士
# 终生爱兔人士
# 战兔仰慕者
# 终生爱兔人士
# 战兔仰慕者
# 爱兔联盟一号卫
# 钟灵毓秀地下室
# 姊妹报
# 磊落的野心家865
# 章先生家的安修
# lily99996666
# 呆桃赞的77
# 取个昵称总是不能使用
# 我心我主CAO
# 用户7531489840
# 尚好的青春xz
# 墨染曦1005
# 纪红玥
# 我心我主CAO
# 取个名字想到半夜
# 雯子007728
# 七月你好888
# 胡萝卜不是萝卜zz
# lily99996666
# 为战而来1005_XZ
# 和美时光
# 安娜战战的小飞侠
# 胡萝卜不是萝卜zz
# 清风唯战而来
# 青青的黛色
# 半分浅夏_
# 人生若只如初战1005
# 好人一生平安haoya
# 半分浅夏_
# 半分浅夏_
# 纪红玥
# 爱战1005兰草
# 为战而来xz623
# 周周有钱daytoy
# 月儿弯腰123456
# 半分浅夏_
# 半分浅夏_
# 伊人枭赞
# 明月在dyl
# 终生爱兔人士
# 终生爱兔人士
# 战兔仰慕者
# 终生爱兔人士
# 战兔仰慕者
# 爱兔联盟一号卫
# 利安_212
# 雯子007728
# jessie韫
# 冰粉凉虾小火锅_
# 被锤死在坑底
# 冬至莫离1005
# 青色83443
# 随风飞扬xyw
# 用户7433355651
# 我心我主CAO
# 时间遗忘的角落里
# 愉快地呼吸
# 风定犹舞95535
# 飞羽重千
# 我是小耗啊
# 纪红玥
# 我心我主CAO
# xuhong202004
# 秦时明月qinsmoon

# %%
jsontext

# %%
import pymysql
# 引入python中的traceback模块，跟踪错误
import traceback
import sys


class MysqlUtil():
    def __init__(self):
        '''
            初始化方法，连接数据库
        '''
        host = '127.0.0.1'  # 主机名
        user = 'root'  # 数据库用户名
        password = 'Wzh010310'  # 数据库密码
        database = 'weibo'  # 数据库名称
        self.db = pymysql.connect(host=host, user=user, password=password, db=database)  # 建立连接
        self.cursor = self.db.cursor(cursor=pymysql.cursors.DictCursor)  # 设置游标，并将游标设置为字典类型

    def insert(self, sql):
        '''
            插入数据库
            sql:插入数据库的sql语句
        '''
        try:
            # 执行sql语句
            self.cursor.execute(sql)
            # 提交到数据库执行
            self.db.commit()
        except Exception:  # 方法一：捕获所有异常
            # 如果发生异常，则回滚
            print("发生异常", Exception)
            self.db.rollback()
        finally:
            # 最终关闭数据库连接
            self.db.close()

    def fetchone(self, sql):
        '''
            查询数据库：单个结果集
            fetchone(): 该方法获取下一个查询结果集。结果集是一个对象
        '''
        try:
            # 执行sql语句
            self.cursor.execute(sql)
            result = self.cursor.fetchone()
        except:  # 方法二：采用traceback模块查看异常
            # 输出异常信息
            traceback.print_exc()
            # 如果发生异常，则回滚
            self.db.rollback()
            result = 'None'

        finally:
            # 最终关闭数据库连接
            self.db.close()
        return result

    def fetchall(self, sql):
        '''
            查询数据库：多个结果集
            fetchall(): 接收全部的返回结果行.
        '''
        try:
            # 执行sql语句
            self.cursor.execute(sql)
            results = self.cursor.fetchall()
        except:  # 方法三：采用sys模块回溯最后的异常
            # 输出异常信息
            info = sys.exc_info()
            print(info[0], ":", info[1])
            # 如果发生异常，则回滚
            self.db.rollback()
            results = 'None'
        finally:
            # 最终关闭数据库连接
            self.db.close()
        return results

    def delete(self, sql):
        '''
            删除结果集
        '''
        try:
            # 执行sql语句
            self.cursor.execute(sql)
            self.db.commit()
        except:  # 把这些异常保存到一个日志文件中，来分析这些异常
            # 将错误日志输入到目录文件中
            f = open("\log.txt", 'a')
            traceback.print_exc(file=f)
            f.flush()
            f.close()
            # 如果发生异常，则回滚
            self.db.rollback()
        finally:
            # 最终关闭数据库连接
            self.db.close()

    def update(self, sql):
        '''
            更新结果集
        '''
        try:
            # 执行sql语句
            self.cursor.execute(sql)
            self.db.commit()
        except:
            # 如果发生异常，则回滚
            self.db.rollback()
        finally:
            # 最终关闭数据库连接
            self.db.close()

# %%
for node in data['links']:
    print(node)

# %%
import json
from pyecharts import options as opts
from pyecharts.charts import Sankey



with open(title+'.json', "r", encoding="utf-8") as f:
    j = json.load(f)

c = (
    Sankey(
        init_opts=opts.InitOpts(width="1600px", height="800px")

    )
    .add(
        "sankey",
        nodes=j["nodes"],
        links=j["links"],
        pos_top="10%",

        levels=[
            opts.SankeyLevelsOpts(
                depth=0,
                itemstyle_opts=opts.ItemStyleOpts(color="#fbb4ae"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=1,
                itemstyle_opts=opts.ItemStyleOpts(color="#b3cde3"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=2,
                itemstyle_opts=opts.ItemStyleOpts(color="#ccebc5"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=3,
                itemstyle_opts=opts.ItemStyleOpts(color="#decbe4"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
        ],

        linestyle_opt=opts.LineStyleOpts(curve=0.5),
        label_opts=opts.LabelOpts(position="right"),
        focus_node_mode="adjacency",


    )
    .set_global_opts(

        title_opts=opts.TitleOpts(title="Sankey-Level Settings"),
        tooltip_opts=opts.TooltipOpts(trigger="item", trigger_on="mousemove"),

    )
    
)
    

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce3ea8aa8c21432581788bd6a67a68ef" style="width:1600px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce3ea8aa8c21432581788bd6a67a68ef = echarts.init(
#                     document.getElementById('ce3ea8aa8c21432581788bd6a67a68ef'), 'white', {renderer: 'canvas'});
#                 var option_ce3ea8aa8c21432581788bd6a67a68ef = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "\u8096\u6218\u5f71\u97f3\u4f1a\u5b98\u5fae"
#                 },
#                 {
#                     "name": "\u8096\u6218\u5de5\u4f5c\u5ba4"
#                 },
#                 {
#                     "name": "\u767d\u9c7cyuzq2009"
#                 },
#                 {
#                     "name": "\u63d0\u62c9\u7c73\u82cf\u914d\u5267\u4e36"
#                 },
#                 {
#                     "name": "\u8096\u62181005\u53f7\u5b89\u5229\u7b52"
#                 },
#                 {
#                     "name": "lily99996666"
#                 },
#                 {
#                     "name": "\u88ab\u9524\u6b7b\u5728\u5751\u5e95"
#                 },
#                 {
#                     "name": "\u548c\u7f8e\u65f6\u5149"
#                 },
#                 {
#                     "name": "\u5c1a\u597d\u7684\u9752\u6625xz"
#                 },
#                 {
#                     "name": "\u9752\u9752\u7684\u9edb\u8272"
#                 },
#                 {
#                     "name": "\u5b89\u9713789"
#                 },
#                 {
#                     "name": "\u968f\u98ce\u98de\u626cxyw"
#                 },
#                 {
#                     "name": "\u65ad\u820d\u79bb\u81ea\u96be\u5fd8"
#                 },
#                 {
#                     "name": "\u534a\u5206\u6d45\u590f_"
#                 },
#                 {
#                     "name": "\u60ca\u4e16\u516c\u5b50"
#                 },
#                 {
#                     "name": "\u6e05\u98ce\u552f\u6218\u800c\u6765"
#                 },
#                 {
#                     "name": "\u6211\u662f\u5c0f\u8017\u554a"
#                 },
#                 {
#                     "name": "\u751c\u6a59\u5c0f\u5a1c"
#                 },
#                 {
#                     "name": "\u4f0a\u4eba\u67ad\u8d5e"
#                 },
#                 {
#                     "name": "\u6d45\u590f\u9633\u5149ai"
#                 },
#                 {
#                     "name": "\u79e6\u65f6\u660e\u6708qinsmoon"
#                 },
#                 {
#                     "name": "\u6211\u5fc3\u6211\u4e3bCAO"
#                 },
#                 {
#                     "name": "\u60f9\u6211\u8001\u516c\u4f60\u5c31\u6b7b\u5b9a\u4e86"
#                 },
#                 {
#                     "name": "\u4e3d\u8389\u65af_\u65fa"
#                 },
#                 {
#                     "name": "\u9752\u827283443"
#                 },
#                 {
#                     "name": "\u68a6\u66e6\u8c46\u8c46"
#                 },
#                 {
#                     "name": "\u845b\u845b\u5f00\u5fc3"
#                 },
#                 {
#                     "name": "\u626f\u626f\u5c31\u662f\u6211"
#                 },
#                 {
#                     "name": "\u5b89\u5a1c\u6218\u6218\u7684\u5c0f\u98de\u4fa0"
#                 },
#                 {
#                     "name": "\u51cc\u67ab\u9759\u5fc32020"
#                 },
#                 {
#                     "name": "\u5fae\u96e8\u6fdb\u6fdb"
#                 },
#                 {
#                     "name": "\u591c\u672a\u592eyez"
#                 },
#                 {
#                     "name": "\u8424\u8424\u706b\u4e4b\u68ee\u6797"
#                 },
#                 {
#                     "name": "\u8096\u6218\u7f51\u5ba3\u5b98\u5fae"
#                 },
#                 {
#                     "name": "\u6a59\u82b1\u5154\u5b50sean"
#                 },
#                 {
#                     "name": "\u7231\u5154\u8054\u76df\u4e00\u53f7\u536b"
#                 },
#                 {
#                     "name": "\u58a8\u67d3\u66e61005"
#                 },
#                 {
#                     "name": "\u7ec8\u751f\u7231\u5154\u4eba\u58eb"
#                 },
#                 {
#                     "name": "\u8096\u67d3\u67d3\u7684\u5c0f\u5154\u7259"
#                 },
#                 {
#                     "name": "\u8fd9\u6837\u76f8\u7231U"
#                 },
#                 {
#                     "name": "\u51b0\u7c89\u51c9\u867e\u5c0f\u706b\u9505_"
#                 },
#                 {
#                     "name": "MissLiu_1005"
#                 },
#                 {
#                     "name": "\u624b\u6367\u661f\u5149\u9001\u4f60"
#                 },
#                 {
#                     "name": "\u53d6\u4e2a\u6635\u79f0\u603b\u662f\u4e0d\u80fd\u4f7f\u7528"
#                 },
#                 {
#                     "name": "Nana_1005"
#                 },
#                 {
#                     "name": "xuhong202004"
#                 },
#                 {
#                     "name": "\u5154\u6bdb\u62a4\u7406\u624b\u518c"
#                 },
#                 {
#                     "name": "\u8096\u8096\u96c5\u6960"
#                 },
#                 {
#                     "name": "\u96ef\u5b50007728"
#                 },
#                 {
#                     "name": "jessie\u97eb"
#                 },
#                 {
#                     "name": "\u597d\u4eba\u4e00\u751f\u5e73\u5b89haoya"
#                 },
#                 {
#                     "name": "\u53d6\u4e2a\u540d\u5b57\u60f3\u5230\u534a\u591c"
#                 },
#                 {
#                     "name": "\u5468\u5468\u6709\u94b1daytoy"
#                 },
#                 {
#                     "name": "\u90a3\u5e74\u7684\u51491221"
#                 },
#                 {
#                     "name": "\u6109\u5feb\u5730\u547c\u5438"
#                 },
#                 {
#                     "name": "\u66fc\u4ec0\u4e48\u57fa\u4ec0\u4e48\u5eb7\u4ec0\u4e48"
#                 },
#                 {
#                     "name": "\u4e3a\u6218\u800c\u67651005_XZ"
#                 },
#                 {
#                     "name": "\u78ca\u843d\u7684\u91ce\u5fc3\u5bb6865"
#                 },
#                 {
#                     "name": "\u871c\u8c46\u8c46\u6c99"
#                 },
#                 {
#                     "name": "lisa\u7231\u6843\u6843"
#                 },
#                 {
#                     "name": "Selamm\u521d\u5fc3"
#                 },
#                 {
#                     "name": "\u660e\u6708\u5728dyl"
#                 },
#                 {
#                     "name": "\u65e0\u8bed\u6d1b"
#                 },
#                 {
#                     "name": "\u80e1\u841d\u535c\u4e0d\u662f\u841d\u535czz"
#                 },
#                 {
#                     "name": "\u6708\u513f\u5f2f\u8170123456"
#                 },
#                 {
#                     "name": "\u7a97\u5916\u68a7\u6850\u53d1\u65b0\u82bd"
#                 },
#                 {
#                     "name": "\u730b\u730b\u5927\u961f\u957f"
#                 },
#                 {
#                     "name": "\u5c0f\u7ea2\u82b1\u7684\u5e78\u798f\u751f\u6d3b"
#                 },
#                 {
#                     "name": "\u5446\u6843\u71da"
#                 },
#                 {
#                     "name": "\u51ac\u81f3\u83ab\u79bb1005"

# %%
count_number

# %%
import json
import random
title="肖战工作室"
sql_3 = f'SELECT * FROM weiboforword where title="{title}" ORDER BY `publish_time`'
db = MysqlUtil()
count_number = db.fetchall(sql_3)
kk=[]

for row in count_number:
    if row["source"] not in kk:
        kk.append(row["source"])
    if row["target"] not in kk:
        kk.append(row["target"])

dict_name={}
dict_name_fan={}
id=1
for i in range(len(kk)):
    dict_name[kk[i]]=id
    id=id+1
id=1
for i in range(len(kk)):
    dict_name_fan[id]=kk[i]
    id=id+1
import random

  
jsontext = {"categories":[],"nodes":[],"links":[]}
jsontext["categories"]=[{'name': '类目0'},{'name': '类目1'},{'name': '类目2'},{'name': '类目3'},{'name': '类目4'},{'name': '类目5'},{'name': '类目6'},{'name': '类目7'},{'name': '类目8'}]

for row in kk:
    id=id-1
    jsontext["nodes"].append({'id': dict_name[row],
  'name': row,
  'symbolSize': 15,
  'label': {'normal': {'show': True}},
  'category': random.randint(0,7)})
    id=id+1



for row in count_number: 
    jsontext["links"].append({'source': dict_name[row['source']], 'target': dict_name[row['target']] ,'time':row['publish_time'].strftime("%Y-%m-%d %H:%M:%S")}) 
    id=id+1


  
jsontext = {"categories":[],"nodes":[],"links":[]}
jsontext["categories"]=[{'name': '类目0'},{'name': '类目1'},{'name': '类目2'},{'name': '类目3'},{'name': '类目4'},{'name': '类目5'},{'name': '类目6'},{'name': '类目7'},{'name': '类目8'}]

for row in kk:
    id=id-1
    jsontext["nodes"].append({'id': dict_name[row],
  'name': row,
  'symbolSize': 15,
  'label': {'normal': {'show': True}},
  'category': random.randint(0,7)})
    id=id+1



for row in count_number: 
    jsontext["links"].append({'source': dict_name[row['source']], 'target': dict_name[row['target']] ,'time':row['publish_time'].strftime("%Y-%m-%d %H:%M:%S")}) 
    id=id+1

jsontext=json.dumps(jsontext)
file = open('filename.json', 'w')

file.write(jsontext)

file.close()

# %%
from pyecharts.globals import CurrentConfig, NotebookType
import json
from pyecharts import options as opts
from pyecharts.charts import Graph, Timeline

tl = Timeline(init_opts=opts.InitOpts(width="1500px", height="900px"))

with open("filename.json", "r", encoding="utf-8") as f:
    j = json.load(f)
    nodes = j["nodes"]
    
    categories = j["categories"]

for i in range(len(j['links'])):
    tt=i
    links=j["links"][0:i]
    list_links=[]
    for i in range(len(links)):
        list_links.append(dict_name_fan[links[i]["source"]])
        list_links.append(dict_name_fan[links[i]["target"]])
    list_nodes=[]
    for i in range(len(j["nodes"])):
        if j["nodes"][i]["name"] in list_links:
            list_nodes.append(j["nodes"][i])
    
    i=i+1
    c = (
    Graph(init_opts=opts.InitOpts(width="1700px", height="1000px"))
    .add(
        "",
        nodes=list_nodes,
        links=links,
        categories=categories,
        layout="circular",
        is_rotate_label=True,
        linestyle_opts=opts.LineStyleOpts(color="source", curve=0.3),
        label_opts=opts.LabelOpts(position="right"),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Graph-Les Miserables"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_left="2%", pos_top="20%"),
    )
    )
    tl.add(c, "{}".format(j["links"][tt]['time']))
    tl.add_schema(
    play_interval=400,      # 自动播放的时间间隔，单位毫秒
    is_timeline_show=True,   # 是否显示自动播放的时候，显示时间线（默认 True）
    is_auto_play=True,       # 是否在自动播放（默认 False）
    is_loop_play=True        # 是否循环自动播放（默认 True）
    )

tl.render("123123.html")
# Out:
# '/Users/weizhihao/Documents/GitHub/biye_weibo/代码/123123.html'

# %%
for row in count_number:
#     jsontext["links"].append({"source":row["source"],"target":row["target"],"value":row["value"]})
    if row['source'] in row['target']:
        jsontext["links"].append({"source":row["source"],"target":row["target"],"value":row["value"]})
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False

# %%
import json
from pyecharts import options as opts
from pyecharts.charts import Sankey


title="蔡徐坤"

sql_3 = f'SELECT * FROM weiboforword where title="{title}"'
db = MysqlUtil()
count_number = db.fetchall(sql_3)
kk=[]
# 数据库方式
for row in count_number:
    kk.append("蔡徐坤")
    kk.append(row["source"])
    kk.append(row["target"])
kk = list(set(kk))
import json

# 数据库
jsontext = {"nodes":[],"links":[]}
for row in kk:
    jsontext["nodes"].append({"name":row})
for row in count_number:
    if row['source'] in row['target']:
        continue
    jsontext["links"].append({"source":row["source"],"target":row["target"],"value":row["value"]})
jsontext=json.dumps(jsontext)
file = open(title+'.json', 'w')
file.write(jsontext)
file.close()

with open(title+'.json', "r", encoding="utf-8") as f:
    j = json.load(f)

c = (
    Sankey(
        init_opts=opts.InitOpts(width="1600px", height="800px")

    )
    .add(
        "转发关系",
        nodes=j["nodes"],
        links=j["links"],
        pos_top="10%",

        levels=[
            opts.SankeyLevelsOpts(
                depth=0,
                itemstyle_opts=opts.ItemStyleOpts(color="#fbb4ae"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=1,
                itemstyle_opts=opts.ItemStyleOpts(color="#b3cde3"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=2,
                itemstyle_opts=opts.ItemStyleOpts(color="#ccebc5"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=3,
                itemstyle_opts=opts.ItemStyleOpts(color="#decbe4"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
        ],

        linestyle_opt=opts.LineStyleOpts(curve=0.5),
        label_opts=opts.LabelOpts(position="right"),
        focus_node_mode="adjacency",


    )
    .set_global_opts(

        title_opts=opts.TitleOpts(title="桑基关系图"),
        tooltip_opts=opts.TooltipOpts(trigger="item", trigger_on="mousemove"),

    )

)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d97ec533b2714c52aecef66c1c40fd82" style="width:1600px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d97ec533b2714c52aecef66c1c40fd82 = echarts.init(
#                     document.getElementById('d97ec533b2714c52aecef66c1c40fd82'), 'white', {renderer: 'canvas'});
#                 var option_d97ec533b2714c52aecef66c1c40fd82 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "\u8f6c\u53d1\u5173\u7cfb",
#             "data": [
#                 {
#                     "name": "\u8521\u5f90\u5764"
#                 },
#                 {
#                     "name": "No_Pretending"
#                 },
#                 {
#                     "name": "\u8521\u5f90\u576482\u53f7\u55b5\u661f\u7403"
#                 },
#                 {
#                     "name": "\u7cd6\u7403\u6ce1\u8521Elaine_K"
#                 },
#                 {
#                     "name": "\u8521\u00b7\u5e74\u7eaa\u8f7b\u8f7b\u00b7\u7edd\u4e0d\u00b7\u8499\u7740\u773c\u00b7\u5f90\u5764"
#                 },
#                 {
#                     "name": "kun-officialclub"
#                 },
#                 {
#                     "name": "\u8521\u5f90\u5764\u00b7KUNMMT"
#                 },
#                 {
#                     "name": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae"
#                 },
#                 {
#                     "name": "\u98ce\u6708\u7686\u68a62011"
#                 },
#                 {
#                     "name": "August_fok"
#                 },
#                 {
#                     "name": "\u597d\u6b21\u7684\u8106\u76ae\u7126\u7cd6\u6155\u65af\u732a"
#                 },
#                 {
#                     "name": "\u75af\u4e86\u6210\u5996\u7ee7\u7eed\u71e5"
#                 },
#                 {
#                     "name": "\u5764\u56fd\u7b2c\u4e00\u4fdd\u5b89\u5927\u961f\u961f\u957f\u7403"
#                 },
#                 {
#                     "name": "\u732a\u54aa\u724c\u5bbd\u7c89"
#                 },
#                 {
#                     "name": "\u58a8\u8a00\u8981\u597d\u8fd0\u66b4\u5bcc"
#                 },
#                 {
#                     "name": "ikun\u7fe9\u7fe9"
#                 },
#                 {
#                     "name": "\u8521\u5f90\u5764\u5de5\u4f5c\u5ba4"
#                 },
#                 {
#                     "name": "\u8521\u5f90\u5764\u5168\u7403\u7c89\u4e1d\u540e\u63f4\u4f1a"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "276081"
#                 },
#                 {
#                     "source": "\u8521\u5f90\u576482\u53f7\u55b5\u661f\u7403",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "75839"
#                 },
#                 {
#                     "source": "\u8521\u5f90\u5764\u00b7KUNMMT",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "128257"
#                 },
#                 {
#                     "source": "\u8521\u5f90\u5764\u5de5\u4f5c\u5ba4",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "22695"
#                 },
#                 {
#                     "source": "ikun\u7fe9\u7fe9",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "14684"
#                 },
#                 {
#                     "source": "\u8521\u5f90\u5764\u5168\u7403\u7c89\u4e1d\u540e\u63f4\u4f1a",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "111378"
#                 },
#                 {
#                     "source": "\u597d\u6b21\u7684\u8106\u76ae\u7126\u7cd6\u6155\u65af\u732a",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "7771"
#                 },
#                 {
#                     "source": "kun-officialclub",
#                     "target": "\u8521\u5f90\u5764",
#                     "value": "15475"
#                 },
#                 {
#                     "source": "\u8521\u5f90\u576482\u53f7\u55b5\u661f\u7403",
#                     "target": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae",
#                     "value": "253095"
#                 },
#                 {
#                     "source": "\u98ce\u6708\u7686\u68a62011",
#                     "target": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae",
#                     "value": "5767"
#                 },
#                 {
#                     "source": "August_fok",
#                     "target": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae",
#                     "value": "5427"
#                 },
#                 {
#                     "source": "\u58a8\u8a00\u8981\u597d\u8fd0\u66b4\u5bcc",
#                     "target": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae",
#                     "value": "5028"
#                 },
#                 {
#                     "source": "\u7cd6\u7403\u6ce1\u8521Elaine_K",
#                     "target": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae",
#                     "value": "5017"
#                 },
#                 {
#                     "source": "No_Pretending",
#                     "target": "\u8521\u5f90\u5764\u7c89\u4e1d\u56e2\u5b98\u5fae",
#                     "value": "17"
#                 },
#                 {
#                     "source": "\u98ce\u6708\u7686\u68a62011",
#                     "target": "\u8521\u5f90\u576482\u53f7\u55b5\u661f\u7403",
#                     "value": "14971"
#                 },
#                 {
#                     "source": "No_Pretending",
#                     "target": "\u8521\u5f90\u576482\u53f7\u55b5\u661f\u7403",
#                     "value": "9340"
#                 },
#                 {
#                     "source": "\u75af\u4e86\u6210\u5996\u7ee7\u7eed\u71e5",
#                     "target": "\u8521\u5f90\u576482\u53f7\u55b5\u661f\u7403",
#                     "value": "8225"
#                 },
#                 {
#                     "source": "\u5764\u56fd\u7b2c\u4e00\u4fdd\u5b89\u5927\u961f\u961f\u957f\u7403",
#                     "target": "\u8521\u5f90\u5764\u00b7KUNMMT",
#                     "value": "10128"
#                 },
#                 {
#                     "source": "\u8521\u00b7\u5e74\u7eaa\u8f7b\u8f7b\u00b7\u7edd\u4e0d\u00b7\u8499\u7740\u773c\u00b7\u5f90\u5764",
#                     "target": "\u8521\u5f90\u5764\u00b7KUNMMT",
#                     "value": "6180"
#                 },
#                 {
#                     "source": "\u732a\u54aa\u724c\u5bbd\u7c89",
#                     "target": "\u8521\u5f90\u5764\u00b7KUNMMT",
#                     "value": "100"
#                 }
#             ],
#             "left": "5%",
#             "top": "10%",
#             "right": "20%",
#             "bottom": "5%",
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "nodeAlign": "justify",
#             "layoutIteration": 32,
#             "orient": "horizontal",
#             "draggable": true,
#             "emphasis": {
#                 "focus": "adjacency"
#             },
#             "levels": [
#                 {
#                     "depth": 0,
#                     "itemStyle": {
#                         "color": "#fbb4ae"
#                     },
#                     "lineStyle": {
#                         "show": tru
